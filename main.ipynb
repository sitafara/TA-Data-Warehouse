# %% [markdown]
# # Toko Baju

# %%
import os
import mysql.connector
import pandas as pd
import datetime 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("baju_wanita.csv")
df
# Out:
#                         city  jumlah_review jumlah_view  \
# 0                    Jakarta           1231      90,600
# 1               Kota Bandung            551      69,100
# 2             Kota Surakarta            442      55,400
# 3                    Jakarta            123      47,700
# 4               Kota Bandung            115       44000
# ...                      ...            ...         ...
# 4498                 Jakarta             33           0
# 4499                 Jakarta             33           0
# 4500                 Jakarta             31           0
# 4501  Kota Tangerang Selatan             18           0
# 4502                 Jakarta             66           0
#
#                     location   price  product_id  quantity_sold  rating  \
# 0                    Jakarta   53000   246580930           3969       5
# 1               Kota Bandung   47000   210908812           1792       5
# 2             Kota Surakarta   20000    71957699           2690       4
# 3                    Jakarta   78000    33447414            277       4
# 4               Kota Bandung   60000   222820000            286       4
# ...                      ...     ...         ...            ...     ...
# 4498                 Jakarta  131500   366339754             99       5
# 4499                 Jakarta  239900   363772675             99       5
# 4500                 Jakarta  105000   358247047             99       5
# 4501  Kota Tangerang Selatan   50000   335503058             99       5
# 4502                 Jakarta  155000   344386624             99       5
#
#                 shop_name subcategory  \
# 0         Chel&#39;z Shop      Piyama
# 1                Openshop      Blouse
# 2             Yona Retail      Daster
# 3       CASHYUPHORIA SHOP      Kemeja
# 4            Hijab Update      Kemeja
# ...                   ...         ...
# 4498  Toko Adela Aloysius     Sweater
# 4499       Toko Wisly Wis    Jumpsuit
# 4500         Strong Woman      Kemeja
# 4501         Michary Shop      Daster
# 4502         Arabela Shop    Jumpsuit
#
#                                                   title Tanggal Pembelian  \
# 0     Baju Tidur Cewek-Wanita Piyama Pajamas Satin M...        28-12-2018
# 1     Atasan Wanita Zara Puff Blouse Tunik Baju Musl...        28-12-2018
# 2     Daster Midi - Baju Tidur Wanita Dress Motif Mu...        26-12-2018
# 3     baju atasan kemeja tunik wanita lengan panjang...        25-12-2018
# 4     Kemeja putih - Baju busui - Atasan wanita mura...        24-12-2018
# ...                                                 ...               ...
# 4498  Couple Sweater Pasangan Wanita Pria Baju Atasa...        13-01-2018
# 4499  Jumpsuit Jumbo Wanita Bigsize Big Size Panjang...         1-12-2018
# 4500  Baju Kemeja Wanita Jumbo Bigsize Big Size Leng...         1-10-2018
# 4501     Daster Tanktop Dress Tanktop Baju Tidur Wanita          1-9-2018
# 4502  Overall Jumpsuit Baju Rok Kodok Ripped Sobek P...          1-9-2018
#
#       quantity
# 0         3969
# 1         1792
# 2         2690
# 3          277
# 4          286
# ...        ...
# 4498        99
# 4499        99
# 4500        99
# 4501        99
# 4502        99
#
# [4503 rows x 13 columns]

# %%
mydb = mysql.connector.connect(host="localhost",user="root",passwd="")
mycursor = mydb.cursor()

# %%
mycursor.execute("DROP DATABASE if exists tokobaju")
mycursor.execute("CREATE DATABASE tokobaju")

# %%
mycursor.execute("use tokobaju")

# %%
mycursor.execute("DROP TABLE if exists kota")
mycursor.execute("DROP TABLE if exists toko")
mycursor.execute("DROP TABLE if exists kategori")
mycursor.execute("DROP TABLE if exists penjualan")
mycursor.execute("create table kota(id_kota int primary key, nama_kota varchar(50) not null)")
mycursor.execute("create table toko(id_toko int primary key, nama_toko varchar(50) not null)")
mycursor.execute("create table kategori(id_kategori int primary key, kategori varchar(50) not null)")
mycursor.execute("create table penjualan(id_penjualan int primary key, quantity int not null, barang varchar(255) not null, harga int not null, tanggal date not null, id_kota int not null, id_toko int not null, id_kategori int not null)")

# %%
mycursor.execute("desc penjualan")
print("tabel penjualan")
for penjualan in mycursor:
    print(penjualan)
    
mycursor.execute("desc kota")
print("tabel kota")
for kota in mycursor:
    print(kota)
    
mycursor.execute("desc kategori")
print("tabel kategori")
for kategori in mycursor:
    print(kategori)
    
mycursor.execute("desc toko")
print("tabel toko")
for toko in mycursor:
    print(toko)
# Out:
# tabel penjualan
# ('id_penjualan', 'int(11)', 'NO', 'PRI', None, '')
# ('quantity', 'int(11)', 'NO', '', None, '')
# ('barang', 'varchar(255)', 'NO', '', None, '')
# ('harga', 'int(11)', 'NO', '', None, '')
# ('tanggal', 'date', 'NO', '', None, '')
# ('id_kota', 'int(11)', 'NO', '', None, '')
# ('id_toko', 'int(11)', 'NO', '', None, '')
# ('id_kategori', 'int(11)', 'NO', '', None, '')
# tabel kota
# ('id_kota', 'int(11)', 'NO', 'PRI', None, '')
# ('nama_kota', 'varchar(50)', 'NO', '', None, '')
# tabel kategori
# ('id_kategori', 'int(11)', 'NO', 'PRI', None, '')
# ('kategori', 'varchar(50)', 'NO', '', None, '')
# tabel toko
# ('id_toko', 'int(11)', 'NO', 'PRI', None, '')
# ('nama_toko', 'varchar(50)', 'NO', '', None, '')

# %%
toko = df['shop_name'].unique()
kategori = df['subcategory'].unique()
kota = df['city'].unique()
penjualan = []
for i,j in df.iterrows():   
    t = -1
    for index, value in enumerate(toko):
        if value == j[8]:
            t = index+1
            break
    
    kat = -1
    for index, value in enumerate(kategori):
        if value == j[9]:
            kat = index+1
            break
        
    kot = -1
    for index, value in enumerate(kota):
        if value == j[0]:
            kot = index+1
    
    penjualan.append([j[12],j[10],j[4],datetime.datetime.strptime(j[11],'%d-%m-%Y').strftime('%Y-%m-%d'),  t, kat, kot])

# %%
mycursor.execute("delete from kota")
for index, i in enumerate(kota): 
    mycursor.execute("INSERT INTO KOTA VALUES(" + str(index+1) + ", '" + str(i) + "')")
    mydb.commit

# %%
mycursor.execute("delete from kategori")
for index, i in enumerate(kategori): 
    mycursor.execute("INSERT INTO KATEGORI VALUES(" + str(index+1) + ", '" + str(i) + "')")
    mydb.commit

# %%
mycursor.execute("delete from toko")
for index, i in enumerate(toko): 
    mycursor.execute("INSERT INTO TOKO VALUES(" + str(index+1) + ", '" + str(i) + "')")
mydb.commit
# Out:
# <bound method MySQLConnection.commit of <mysql.connector.connection.MySQLConnection object at 0x000002040D2A6D30>>

# %%
mycursor.execute("delete from penjualan")
for index, i in enumerate(penjualan): 
    mycursor.execute("INSERT INTO PENJUALAN VALUES(" + str(index+1) + ", " + str(i[0]) + ",'" + str(i[1]) + "'," + str(i[2]) + ",'" + str(i[3]) + "'," + str(i[4]) + "," + str(i[5]) + "," + str(i[6]) + ")")
mydb.commit
# Out:
# <bound method MySQLConnection.commit of <mysql.connector.connection.MySQLConnection object at 0x000002040D2A6D30>>

# %%
mycursor.execute("SELECT * FROM KOTA")

KOTA = []
for row in mycursor.fetchall():
    KOTA.append(row)
print("========================KOTA================================")
print(KOTA)
print("============================================================")

mycursor.execute("SELECT * FROM KATEGORI")
KATEGORI = []
for row in mycursor.fetchall():
    KATEGORI.append(row)
print("========================KATEGORI================================")
print(KATEGORI)
print("============================================================")

mycursor.execute("SELECT * FROM TOKO")
TOKO = []
for row in mycursor.fetchall():
    TOKO.append(row)
print("========================TOKO================================")
print(TOKO)
print("============================================================")

mycursor.execute("SELECT * FROM PENJUALAN")
PENJUALAN = []
for row in mycursor.fetchall():
    PENJUALAN.append(row)
print("========================PENJUALAN================================")
print(PENJUALAN)
print("============================================================")
# Out:
# ========================KOTA================================
# [(1, 'Jakarta'), (2, 'Kota Bandung'), (3, 'Kota Surakarta'), (4, 'Kota Surabaya'), (5, 'Kab. Pekalongan'), (6, 'Kota Depok'), (7, 'Kota Banjar'), (8, 'Kota Denpasar'), (9, 'Kab. Bekasi'), (10, 'Kota Pekalongan'), (11, 'Kota Tangerang'), (12, 'Kota Cirebon'), (13, 'Kota Tangerang Selatan'), (14, 'Kab. Bandung'), (15, 'Kab. Banyumas'), (16, 'Kab. Tangerang'), (17, 'Kab. Pandeglang'), (18, 'Kota Yogyakarta'), (19, 'Kab. Klungkung'), (20, 'Kota Batam'), (21, 'Kab. Nganjuk'), (22, 'Kota Kediri'), (23, 'Kota Bekasi'), (24, 'Kab. Garut'), (25, 'Kab. Bandung Barat'), (26, 'Kota Bogor'), (27, 'Kota Malang'), (28, 'Kota Pasuruan'), (29, 'Kab. Blitar'), (30, 'Kota Medan'), (31, 'Kota Semarang'), (32, 'Kota Salatiga'), (33, 'Kab. Sukoharjo'), (34, 'Kab. Kudus'), (35, 'Kota Cimahi'), (36, 'Kota Batu'), (37, 'Kab. Bogor'), (38, 'Kab. Gianyar'), (39, 'Kab. Sidoarjo'), (40, 'Kab. Jepara'), (41, 'Kab. Sleman'), (42, 'Kab. Magetan'), (43, 'Kab. Klaten'), (44, 'Kab. Bojonegoro'), (45, 'Kab. Sumedang'), (46, 'Kab. Bantul'), (47, 'Kab. Malang'), (48, 'Kab. Ponorogo'), (49, 'Kota Banjarmasin'), (50, 'Kab. Batang'), (51, 'Kab. Serang'), (52, 'Kab. Mojokerto'), (53, 'Kab. Sukabumi')]
# ============================================================
# ========================KATEGORI================================
# [(1, 'Piyama'), (2, 'Blouse'), (3, 'Daster'), (4, 'Kemeja'), (5, 'Maxi Dress'), (6, 'Blouse Batik'), (7, 'Celana Dalam'), (8, 'Batik Couple'), (9, 'Setelan'), (10, 'Tank Top'), (11, 'Vest'), (12, 'Kaos'), (13, 'Celana Panjang'), (14, 'Sweater'), (15, 'Mini Dress'), (16, 'Sneakers'), (17, 'Lingerie'), (18, 'Celana Tidur'), (19, 'Jumpsuit'), (20, 'Midi Dress'), (21, 'Kebaya'), (22, 'Coat'), (23, 'Dress Batik'), (24, 'Rok Midi'), (25, 'Rok Maxi'), (26, 'Jam Tangan Analog'), (27, 'Legging'), (28, 'Cardigan'), (29, 'BRA'), (30, 'Blazer'), (31, 'Celana Jeans'), (32, 'Celana Pendek'), (33, 'Crop Top'), (34, 'Baju Couple'), (35, 'Jaket'), (36, 'G-String'), (37, 'Kain Batik'), (38, 'Hoodie'), (39, 'Polo Shirt'), (40, 'Bros'), (41, 'Manekin'), (42, 'Korset'), (43, 'Scarf & Shawl'), (44, 'Backpack'), (45, 'Rok Mini'), (46, 'Sandal'), (47, 'Jam Tangan Digital')]
# ============================================================
# ========================TOKO================================
# [(1, 'Chel&#39;z Shop'), (2, 'Openshop'), (3, 'Yona Retail'), (4, 'CASHYUPHORIA SHOP'), (5, 'Hijab Update'), (6, 'Dress'), (7, 'Paphika'), (8, 'ISHETA'), (9, 'chantyshop'), (10, 'Glory Purple Shop'), (11, 'AsQueen shop'), (12, 'Euro Bikini'), (13, 'Makmur Tanah Abang'), (14, 'AMALIA-SHOP'), (15, 'Batik Alita'), (16, 'Nina Colecction'), (17, 'VOELTOEZ SHOP'), (18, 'KINARA Storez'), (19, 'rajagrosironline'), (20, 'Yuc Online Shopping'), (21, 'Risna shop'), (22, 'AFWINDO Grosir Fashion'), (23, 'Pikoi_id'), (24, 'redishop'), (25, 'Agung RoKr'), (26, 'myfashion'), (27, 'endang pitrijani'), (28, 'GROSIR KOREAN FASHION'), (29, 'multishop_bdg'), (30, 'Clothing Media Indo'), (31, 'Parrot Computer'), (32, 'Pedkey Butik'), (33, 'luky watch shop'), (34, 'Sakura.Collection'), (35, 'Lingerie Style'), (36, 'RisRus Apparel'), (37, 'Twinz Collections'), (38, 'Amelie Butik Wholesale'), (39, 'inovashion'), (40, 'Djeeva Store'), (41, 'Lobby Mode'), (42, 'RisqianaBatik'), (43, 'Komutan Shop'), (44, 'Vintagelicious'), (45, 'LOVE THE WORLD'), (46, 'Longjohn - Baju winter'), (47, 'Figura Bingkai RAFEL'), (48, 'Albanaa Store'), (49, 'KaraKorea Shop'), (50, 'Grosir Korean style'), (51, 'FashionOnline'), (52, 'Batik Rini'), (53, 'Mekar OS'), (54, 'AA Kasimura'), (55, 'chibishop'), (56, 'Batik Hengky'), (57, 'Tazkia Hijab Store'), (58, 'bohemianshop'), (59, 'THE FASHION ROOM'), (60, 'Arabela Shop'), (61, 'tokochio'), (62, 'TOKO TIGA LEBIH MURAH'), (63, 'Lingerieku'), (64, 'BLOOM online store'), (65, 'Michary Shop'), (66, 'Lacel Dabana Clothing'), (67, 'Zomblo Shop'), (68, 'Miss.Shinee'), (69, 'AMALIA COLLECTION29'), (70, 'Dinara Collection'), (71, 'fashionnisme'), (72, 'Desmira Medika'), (73, 'LEMONE'), (74, 'casis'), (75, 'YUCWHOLESALE'), (76, 'miftakhul hidayah'), (77, 'Batik Jiwangga'), (78, 'Buana-Fashion'), (79, 'Nafa Division'), (80, 'GAYALO'), (81, 'Goodness Weaver'), (82, 'Esrocte'), (83, 'sugeng network'), (84, 'Sarung Tenun Bandung'), (85, 'Uptodate Fashion Shop'), (86, 'jolie costume'), (87, 'Kemeja Slim Fit'), (88, 'Multishop_bandung'), (89, 'ARYAZ OLSHOP'), (90, 'Bikini Secret'), (91, 'GRAFIZH'), (92, 'GUSTIANA STORE'), (93, 'Millennia Fashion'), (94, 'Mecca Storee'), (95, 'Arumi Batik'), (96, 'menara hijab'), (97, 'OXPREY59'), (98, 'Tuasan Store'), (99, 'STAR knitting fashion'), (100, 'GrosirBaju RisHa'), (101, 'Fashionisty Modis'), (102, 'Sahabat Buku Anak'), (103, 'Adila Fashion'), (104, 'INDO_JERSEY'), (105, 'JUDE SHOP'), (106, 'Cinemaz Merchandise'), (107, 'snowlyn'), (108, 'Toko Demen'), (109, 'Size Plus Indonesia'), (110, 'Super Mall Grosir'), (111, 'Laparta Cart'), (112, 'Topholic'), (113, 'Vamaya Shop'), (114, 'B.O.M baju online murah'), (115, 'Louis Casual Design'), (116, 'Twins Fashion Oke'), (117, 'Miuw fashion shop'), (118, 'boutique preloved'), (119, 'Batik Nisa Colection'), (120, 'dua melati'), (121, 'grosir baju keisha'), (122, 'Haneiumi'), (123, 'rahel colecctions'), (124, 'Rafli Rizqi'), (125, 'Tineyfancy'), (126, 'Mrs Bee Bags'), (127, 'BATIK NITNOT BLITAR'), (128, 'Vangie Shop'), (129, 'ellips grosir store'), (130, 'Cute Rossie Shop'), (131, 'SS collection JKT'), (132, 'Bibigsize Fashion'), (133, 'Toko Yuga Ca'), (134, 'Adreena_Storee'), (135, 'anggifamily'), (136, 'fashion sport bekasi'), (137, 'Central Jacket Bandung'), (138, 'Neneng 1'), (139, 'BestInn Store'), (140, 'Flower Stores'), (141, 'Toko Emilda'), (142, 'KAIZA STORE'), (143, 'Toko Adam Hawa'), (144, 'bukitmakmur'), (145, 'RJ-Fashion'), (146, 'Griya Batik SS'), (147, 'Navishaa Store'), (148, 'Bonanza Collection'), (149, 'Shalihat Mode On'), (150, 'SF Julian'), (151, 'widyashopz'), (152, 'KCsleepwear'), (153, 'Nisa Coklat'), (154, 'cilliacessa olshop'), (155, 'OTIN FASHION'), (156, 'Jaspart'), (157, 'RaynerTravelHolix'), (158, 'Youshop Wedrop'), (159, 'pumpkinlicious'), (160, 'Super Model'), (161, 'Gents Lounge'), (162, 'LAVELA ID'), (163, 'D_One Fashions'), (164, 'Strong Woman'), (165, 'Dress Tidur Vina'), (166, 'HEXA STORE&#39;s'), (167, 'BATIKSINDEN'), (168,  ...
# ============================================================
# ========================PENJUALAN================================
# [(1, 3969, 'Baju Tidur Cewek-Wanita Piyama Pajamas Satin Murah', 53000, datetime.date(2018, 12, 28), 1, 1, 1), (2, 1792, 'Atasan Wanita Zara Puff Blouse Tunik Baju Muslim Blus Muslim', 47000, datetime.date(2018, 12, 28), 2, 2, 2), (3, 2690, 'Daster Midi - Baju Tidur Wanita Dress Motif Murah Rayon Adem Seri II', 20000, datetime.date(2018, 12, 26), 3, 3, 3), (4, 277, 'baju atasan kemeja tunik wanita lengan panjang - plaid long blouse', 78000, datetime.date(2018, 12, 25), 4, 4, 1), (5, 286, 'Kemeja putih - Baju busui - Atasan wanita murah : Catty White tunik', 60000, datetime.date(2018, 12, 24), 5, 4, 2), (6, 474, 'Atasan Baju Pakaian Blouse Model Korea Wanita Korean Style Blus Wing', 80000, datetime.date(2018, 12, 23), 6, 2, 1), (7, 551, 'Jumbo Hazelnut Baju Atasan Wanita Bigsize Oversized Spandex Rayon Adem', 71000, datetime.date(2018, 12, 22), 7, 2, 4), (8, 400, 'HEM KENNA TOP | BAJU WANITA | ATASAN LENGAN PANJANG | BLOUSE | BLUS', 44600, datetime.date(2018, 12, 20), 8, 4, 1), (9, 90, 'baju muslim wanita gamis maxi maxy lengan panjang - Visie long dress', 100000, datetime.date(2018, 12, 19), 9, 5, 1), (10, 497, '61116 tabita top-baju batik wanita-baju tunik-atasan muslim wanita', 62000, datetime.date(2018, 12, 17), 10, 6, 1), (11, 308, 'hem love eye kemeja garcon baju atasan wanita', 55000, datetime.date(2018, 12, 17), 11, 4, 1), (12, 670, 'Celana Dalam Wanita Lingerie Gstring Thong Bikini Baju Pakaian Bra BH', 20000, datetime.date(2018, 12, 16), 12, 7, 1), (13, 984, 'Baju Wanita kemeja jumbo polos xxl', 50000, datetime.date(2018, 12, 15), 13, 4, 1), (14, 116, 'BATIK COUPLE SARIMBIT KELUARGA SERAGAM PESTA BAJU MUSLIM KEBAYA WANITA', 225000, datetime.date(2018, 12, 14), 14, 8, 1), (15, 196, 'Blouse Batik Wanita- Atasan Wanita- Baju Kemeja Wanita Batik Kerja 01', 68000, datetime.date(2018, 11, 12), 15, 2, 5), (16, 735, 'Baju Tidur Piyama Pajamas Satin silky velvet Cewek-Wanita Dewasa PP', 58000, datetime.date(2018, 11, 12), 1, 1, 1), (17, 329, 'piyama baju tidur lengan panjang katun kekinian dewasa wanita murah', 69900, datetime.date(2018, 11, 12), 16, 1, 6), (18, 232, 'aop setelan st kodok owl - baju wanita pakaian cewek celana kaos', 56000, datetime.date(2018, 11, 12), 17, 9, 1), (19, 446, 'Tank Top Camisole Tanktop Bra Busa Dalaman Baju Atasan Wanita Seksi', 56000, datetime.date(2018, 10, 12), 18, 10, 1), (20, 200, 'Baju Atasan Wanita Baju Murah Muslim Blus Tunik Hijab Kode IC70004', 69000, datetime.date(2018, 10, 12), 19, 2, 2), (21, 267, 'Blouse Batik Super Jumbo Bigsize Baju Atasan Wanita Big Size 373 vol 2', 78000, datetime.date(2018, 9, 12), 7, 6, 4), (22, 207, 'Big Lolita Blouse Bigsize Baju Atasan Wanita Fashion Spandex Nyaman', 72000, datetime.date(2018, 9, 12), 7, 2, 4), (23, 235, 'Atasan Baju Pakaian Blouse Model Korea Wanita Korean Style Variasi', 80000, datetime.date(2018, 9, 12), 6, 2, 1), (24, 182, 'vest jeans - cardigan - blazer - kimono - outer murah - baju wanita', 69900, datetime.date(2018, 7, 12), 20, 11, 3), (25, 290, 'Jumbo Abigail Blouse Baju Atasan Wanita Bigsize Baju Big Ukuran Besar', 67000, datetime.date(2018, 5, 12), 7, 2, 4), (26, 232, 'Jojoba Jumbo Baju Atasan Wanita Big Size Motif Bunga Lengan Panjang', 68000, datetime.date(2018, 5, 12), 7, 2, 4), (27, 310, 'Jumbo Blooming Owl Baju Atasan Wanita Bigsize Oversized Big', 73000, datetime.date(2018, 4, 12), 7, 2, 4), (28, 240, 'Blouse Batik Super Jumbo Bigsize Baju Atasan Wanita Big Size 373 vol 1', 78000, datetime.date(2018, 4, 12), 7, 6, 4), (29, 250, 'Set Jumpsuit Funny Baju setelan wanita Dewasa ABG Jp Fenny', 59000, datetime.date(2018, 3, 12), 21, 9, 1), (30, 166, 'Back Halter Slim Top Baju Atasan Wanita Sabrina Blouse (BL888)', 69999, datetime.date(2018, 3, 12), 22, 2, 2), (31, 116, 'Baju Batik Wanita Modern - Batik Kantor Murah - Atasan Batik Kerja 791', 79900, datetime.date(2018, 2, 12), 23, 6, 1), (32, 225, 'kaos stripe belang atasan baju wanita lengan panjang size L', 52000, datetime.date(2018, 1, 12), 24, 12, 7), (33, 104, 'baju atasan kem ...
# ============================================================
